# %%
from PIL import Image
import os

def count_images_in_directory(directory, extension):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension):
            count += 1
    return count

def count_images_with_prefix(directory, extension, prefix):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension) and filename.startswith(prefix):
            count += 1
    return count

root_dir = '/content/drive/MyDrive/Main/Dataset/Test_cz'

# jpg 파일 개수 세기
jpg_count = count_images_in_directory(root_dir+'/Images', '.jpg')
print("JPG 파일 개수:", jpg_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Images', '.jpg', 'black_ice')
print("black_ice로 시작하는 JPG 파일 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Images', '.jpg', 'normal')
print("normal로 시작하는 JPG 파일 개수:", normal_png_count)

print("-"*20)

# png 파일 개수 세기
png_count = count_images_in_directory(root_dir+'/Edge', '.png')
print("edge PNG 파일 개수:", png_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'black_ice')
print("black_ice로 시작하는 PNG 파일 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'normal')
print("normal로 시작하는 PNG 파일 개수:", normal_png_count)

print("-"*20)

png_count = count_images_in_directory(root_dir+'/Seg', '.png')
print("seg PNG 파일 개수:", png_count)

# black_ice로 시작하는 jpg 파일 개수 세기
black_ice_jpg_count = count_images_with_prefix(root_dir+'/Seg', '.png', 'black_ice')
print("black_ice로 시작하는 PNG 파일 개수:", black_ice_jpg_count)

# normal로 시작하는 png 파일 개수 세기
normal_png_count = count_images_with_prefix(root_dir+'/Seg', '.png', 'normal')
print("normal로 시작하는 PNG 파일 개수:", normal_png_count)
# Out:
# JPG 파일 개수: 497
# black_ice로 시작하는 JPG 파일 개수: 427
# normal로 시작하는 JPG 파일 개수: 70
# --------------------
# edge PNG 파일 개수: 497
# black_ice로 시작하는 PNG 파일 개수: 427
# normal로 시작하는 PNG 파일 개수: 70
# --------------------
# seg PNG 파일 개수: 497
# black_ice로 시작하는 PNG 파일 개수: 427
# normal로 시작하는 PNG 파일 개수: 70

# %%
import requests
from PIL import Image

from randaugment.randaugment import RandAugment,Cutout

#url = "https://images.pexels.com/photos/356378/pexels-photo-356378.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940"
img = Image.open('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0001.jpg')
random_transform = transforms.Compose(
                        [
                            transforms.RandomHorizontalFlip(p),
                            RandAugment(),
                            transforms.Resize((416, 416)),
                            #ImageNetPolicy(),
                            transforms.ToTensor(),
                            transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225]),
                            transforms.ToPILImage()
                        ])
for i in range(5):
    img_ = random_transform(img)
    img_.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from PIL import Image
import os

def count_images_in_directory(directory, extension):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension):
            count += 1
    return count

def count_images_with_prefix(directory, extension, prefix):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension) and filename.startswith(prefix):
            count += 1
    return count

root_dir = '/content/drive/MyDrive/Dataset/Train'

# jpg 파일 개수 세기
jpg_count = count_images_in_directory(root_dir+'/Img', '.jpg')
print("JPG 파일 개수:", jpg_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Img', '.jpg', 'black_ice')
print("black_ice로 시작하는 JPG 파일 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Img', '.jpg', 'normal')
print("normal로 시작하는 JPG 파일 개수:", normal_png_count)

print("-"*20)

# png 파일 개수 세기
png_count = count_images_in_directory(root_dir+'/Edge', '.png')
print("edge PNG 파일 개수:", png_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'black_ice')
print("black_ice로 시작하는 PNG 파일 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'normal')
print("normal로 시작하는 PNG 파일 개수:", normal_png_count)

print("-"*20)

png_count = count_images_in_directory(root_dir+'/Mask', '.png')
print("seg PNG 파일 개수:", png_count)

# black_ice로 시작하는 jpg 파일 개수 세기
black_ice_jpg_count = count_images_with_prefix(root_dir+'/Mask', '.png', 'black_ice')
print("black_ice로 시작하는 PNG 파일 개수:", black_ice_jpg_count)

# normal로 시작하는 png 파일 개수 세기
normal_png_count = count_images_with_prefix(root_dir+'/Mask', '.png', 'normal')
print("normal로 시작하는 PNG 파일 개수:", normal_png_count)
# Out:
# JPG 파일 개수: 2000
# black_ice로 시작하는 JPG 파일 개수: 1491
# normal로 시작하는 JPG 파일 개수: 509
# --------------------
# edge PNG 파일 개수: 2000
# black_ice로 시작하는 PNG 파일 개수: 1491
# normal로 시작하는 PNG 파일 개수: 509
# --------------------
# seg PNG 파일 개수: 2000
# black_ice로 시작하는 PNG 파일 개수: 1491
# normal로 시작하는 PNG 파일 개수: 509

# %%
from PIL import Image
import os

def count_images_in_directory(directory, extension):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension):
            count += 1
    return count

def count_images_with_prefix(directory, extension, prefix):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension) and filename.startswith(prefix):
            count += 1
    return count

root_dir = '/content/drive/MyDrive/Dataset/Test'

# jpg 파일 개수 세기
jpg_count = count_images_in_directory(root_dir+'/Img', '.jpg')
print("JPG 파일 개수:", jpg_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Img', '.jpg', 'black_ice')
print("black_ice로 시작하는 JPG 파일 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Img', '.jpg', 'normal')
print("normal로 시작하는 JPG 파일 개수:", normal_png_count)

print("-"*20)

# png 파일 개수 세기
png_count = count_images_in_directory(root_dir+'/Edge', '.png')
print("edge PNG 파일 개수:", png_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'black_ice')
print("black_ice로 시작하는 PNG 파일 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'normal')
print("normal로 시작하는 PNG 파일 개수:", normal_png_count)

print("-"*20)

png_count = count_images_in_directory(root_dir+'/Mask', '.png')
print("seg PNG 파일 개수:", png_count)

# black_ice로 시작하는 jpg 파일 개수 세기
black_ice_jpg_count = count_images_with_prefix(root_dir+'/Mask', '.png', 'black_ice')
print("black_ice로 시작하는 PNG 파일 개수:", black_ice_jpg_count)

# normal로 시작하는 png 파일 개수 세기
normal_png_count = count_images_with_prefix(root_dir+'/Mask', '.png', 'normal')
print("normal로 시작하는 PNG 파일 개수:", normal_png_count)
# Out:
# JPG 파일 개수: 976
# black_ice로 시작하는 JPG 파일 개수: 640
# normal로 시작하는 JPG 파일 개수: 336
# --------------------
# edge PNG 파일 개수: 976
# black_ice로 시작하는 PNG 파일 개수: 640
# normal로 시작하는 PNG 파일 개수: 336
# --------------------
# seg PNG 파일 개수: 976
# black_ice로 시작하는 PNG 파일 개수: 640
# normal로 시작하는 PNG 파일 개수: 336

# %%
# !pip install albumentations

# %%
import albumentations as A
import cv2
import matplotlib.pyplot as plt

# %%
def visualize(image, mask, original_image=None, original_mask=None):
    fontsize = 18

    if original_image is None and original_mask is None:
        f, ax = plt.subplots(2, 1, figsize=(8, 8))

        ax[0].imshow(image)
        ax[1].imshow(mask)
    else:
        f, ax = plt.subplots(2, 2, figsize=(6, 6))

        ax[0, 0].imshow(original_image)
        ax[0, 0].set_title('Original image', fontsize=fontsize)

        ax[1, 0].imshow(original_mask)
        ax[1, 0].set_title('Original mask', fontsize=fontsize)

        ax[0, 1].imshow(image)
        ax[0, 1].set_title('Transformed image', fontsize=fontsize)

        ax[1, 1].imshow(mask)
        ax[1, 1].set_title('Transformed mask', fontsize=fontsize)

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Seg/black_ice_0001.png')

aug = A.GridDistortion(distort_limit=0.5, p=1)

#random.seed(5)
augmented = aug(image=image, mask=mask)

image_grid = augmented['image']
mask_grid = augmented['mask']

print(False in (mask == mask_grid))
visualize(image_grid, mask_grid, original_image=image, original_mask=mask)
# Out:
# True

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Seg/black_ice_0001.png')

aug = A.RandomFog(fog_coef_lower=0.3, fog_coef_upper=0.4, p=1)

#random.seed(5)
augmented = aug(image=image, mask=mask)

image_grid = augmented['image']
mask_grid = augmented['mask']

visualize(image_grid, mask_grid, original_image=image, original_mask=mask)

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Seg/black_ice_0001.png')

aug = A.Affine(translate_percent={'y':-.12}, p=1)

#random.seed(5)
augmented = aug(image=image, mask=mask)

image_grid = augmented['image']
mask_grid = augmented['mask']

visualize(image_grid, mask_grid, original_image=image, original_mask=mask)

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Seg/black_ice_0001.png')

aug = A.GaussNoise(var_limit=(25.0, 75.0), mean=50.0, p=1)

#random.seed(5)
augmented = aug(image=image, mask=mask)

image_grid = augmented['image']
mask_grid = augmented['mask']

print(False in (mask == mask_grid))
visualize(image_grid, mask_grid, original_image=image, original_mask=mask)
# Out:
# False

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0001.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Seg/black_ice_0001.png')

aug = A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.2, p=1)

#random.seed(5)
augmented = aug(image=image, mask=mask)

image_grid = augmented['image']
mask_grid = augmented['mask']

print(False in (mask == mask_grid))
visualize(image_grid, mask_grid, original_image=image, original_mask=mask)
# Out:
# False

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0096.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
edge = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Edge/black_ice_0096.png')

aug = A.FancyPCA(p=1)

#random.seed(5)
augmented = aug(image=image, mask=edge)

image_grid = augmented['image']
mask_grid = augmented['mask']

visualize(image_grid, mask_grid, original_image=image, original_mask=edge)

# %%
image = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Images/black_ice_0301.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
mask = cv2.imread('/content/drive/MyDrive/Main/Dataset/Train_jp/Seg/black_ice_0301.png', cv2.IMREAD_GRAYSCALE)

aug = A.CoarseDropout(max_holes=10, max_height=50, max_width=50, min_holes=3, mask_fill_value=True, p=1)

#random.seed(5)
augmented = aug(image=image, mask=mask)

image_grid = augmented['image']
mask_grid = augmented['mask']

visualize(image_grid, mask_grid, original_image=image, original_mask=mask)

# %% [markdown]
# ## 증강 시작

# %%
from PIL import Image
import os

def count_images_in_directory(directory, extension):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension):
            count += 1
    return count

def count_images_with_prefix(directory, extension, prefix):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith(extension) and filename.startswith(prefix):
            count += 1
    return count

root_dir = '/content/drive/MyDrive/Dataset/Train'

# Img 폴더 개수 세기
print('원본 이미지')
jpg_count = count_images_in_directory(root_dir+'/Img', '.jpg')
print("총 개수:", jpg_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Img', '.jpg', 'black_ice')
print("블랙아이스 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Img', '.jpg', 'normal')
print("일반도로 개수:", normal_png_count)

print("-"*20)

# Edge 폴더 개수 세기
print('엣지 이미지')
png_count = count_images_in_directory(root_dir+'/Edge', '.png')
print("총 개수:", png_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'black_ice')
print("블랙아이스 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Edge', '.png', 'normal')
print("일반도로 개수:", normal_png_count)

print("-"*20)

# Mask 폴더 개수 세기
print('마스크 이미지')
png_count = count_images_in_directory(root_dir+'/Mask', '.png')
print("seg PNG 파일 개수:", png_count)

black_ice_jpg_count = count_images_with_prefix(root_dir+'/Mask', '.png', 'black_ice')
print("블랙아이스 개수:", black_ice_jpg_count)

normal_png_count = count_images_with_prefix(root_dir+'/Mask', '.png', 'normal')
print("일반도로 개수:", normal_png_count)
# Out:
# 원본 이미지
# 총 개수: 12000
# 블랙아이스 개수: 8946
# 일반도로 개수: 3054
# --------------------
# 엣지 이미지
# 총 개수: 12000
# 블랙아이스 개수: 8946
# 일반도로 개수: 3054
# --------------------
# 마스크 이미지
# seg PNG 파일 개수: 12000
# 블랙아이스 개수: 8946
# 일반도로 개수: 3054

# %%
data_images = []
check = []
for img_list in os.listdir('/content/drive/MyDrive/Dataset/Train/Edge'):
    data_images.append(img_list)
    if img_list.split('.')[0].endswith('GN'):
        check.append(img_list)

len(data_images)
# Out:
# 12000

# %%
len(check)
# Out:
# 2000

# %%
import albumentations as A
import cv2
import os

root_dir = '/content/drive/MyDrive/Dataset/Train/'
save_dir = '/content/drive/MyDrive/Dataset/Train/'

count = 1
aug = A.GridDistortion(distort_limit=0.25, p=1)

for img_list in data_images:
    img_name = img_list.split('.')[0]
    image = cv2.imread(root_dir+'Img/{}.jpg'.format(img_name))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # mask = cv2.imread(root_dir+'Mask/{}.png'.format(img_name))
    mask = cv2.imread(root_dir+'Edge/{}.png'.format(img_name))

    augmented = aug(image=image, mask=mask)
    image_gd = augmented['image']
    mask_gd = augmented['mask']

    print('count: {}'.format(count))
    # cv2.imwrite(save_dir+'/Img/'+'{}_GD.jpg'.format(img_name), image_gd)
    # print('증강된 이미지 저장 완료: {}_GD.jpg'.format(img_name))
    # cv2.imwrite(save_dir+'/Mask/'+'{}_GD.png'.format(img_name), mask_gd)
    # print('증강된 마스크 저장 완료: {}_GD.png'.format(img_name))
    cv2.imwrite(save_dir+'/Edge/'+'{}_GD.png'.format(img_name), mask_gd)
    print('증강된 엣지 저장 완료: {}_GD.png'.format(img_name))
    print('-'*30)

    count += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 증강된 엣지 저장 완료: black_ice_0543_GD.png
# ------------------------------
# count: 335
# 증강된 엣지 저장 완료: black_ice_1838_GD.png
# ------------------------------
# count: 336
# 증강된 엣지 저장 완료: black_ice_1842_GD.png
# ------------------------------
# count: 337
# 증강된 엣지 저장 완료: black_ice_0813_GD.png
# ------------------------------
# count: 338
# 증강된 엣지 저장 완료: black_ice_1706_GD.png
# ------------------------------
# count: 339
# 증강된 엣지 저장 완료: black_ice_0104_GD.png
# ------------------------------
# count: 340
# 증강된 엣지 저장 완료: black_ice_1184_GD.png
# ------------------------------
# count: 341
# 증강된 엣지 저장 완료: black_ice_0864_GD.png
# ------------------------------
# count: 342
# 증강된 엣지 저장 완료: black_ice_1680_GD.png
# ------------------------------
# count: 343
# 증강된 엣지 저장 완료: black_ice_0662_GD.png
# ------------------------------
# count: 344
# 증강된 엣지 저장 완료: black_ice_0103_GD.png
# ------------------------------
# count: 345
# 증강된 엣지 저장 완료: black_ice_1134_GD.png
# ...

# %%
import albumentations as A
import cv2
import os

root_dir = '/content/drive/MyDrive/Dataset/Train/'
save_dir = '/content/drive/MyDrive/Dataset/Train/'

count = 1
aug = A.RandomFog(fog_coef_lower=0.3, fog_coef_upper=0.4, p=1)

for img_list in data_images:
    img_name = img_list.split('.')[0]
    image = cv2.imread(root_dir+'Img/{}.jpg'.format(img_name))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # mask = cv2.imread(root_dir+'Mask/{}.png'.format(img_name))
    mask = cv2.imread(root_dir+'Edge/{}.png'.format(img_name))

    augmented = aug(image=image, mask=mask)
    image_rf = augmented['image']
    mask_rf = augmented['mask']

    print('count: {}'.format(count))
    # cv2.imwrite(save_dir+'/Img/'+'{}_RF.jpg'.format(img_name), image_rf)
    # print('증강된 이미지 저장 완료: {}_RF.jpg'.format(img_name))
    # cv2.imwrite(save_dir+'/Mask/'+'{}_RF.png'.format(img_name), mask_rf)
    # print('증강된 마스크 저장 완료: {}_RF.png'.format(img_name))
    cv2.imwrite(save_dir+'/Edge/'+'{}_RF.png'.format(img_name), mask_rf)
    print('증강된 엣지 저장 완료: {}_RF.png'.format(img_name))
    print('-'*30)

    count += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 증강된 엣지 저장 완료: black_ice_0543_RF.png
# ------------------------------
# count: 335
# 증강된 엣지 저장 완료: black_ice_1838_RF.png
# ------------------------------
# count: 336
# 증강된 엣지 저장 완료: black_ice_1842_RF.png
# ------------------------------
# count: 337
# 증강된 엣지 저장 완료: black_ice_0813_RF.png
# ------------------------------
# count: 338
# 증강된 엣지 저장 완료: black_ice_1706_RF.png
# ------------------------------
# count: 339
# 증강된 엣지 저장 완료: black_ice_0104_RF.png
# ------------------------------
# count: 340
# 증강된 엣지 저장 완료: black_ice_1184_RF.png
# ------------------------------
# count: 341
# 증강된 엣지 저장 완료: black_ice_0864_RF.png
# ------------------------------
# count: 342
# 증강된 엣지 저장 완료: black_ice_1680_RF.png
# ------------------------------
# count: 343
# 증강된 엣지 저장 완료: black_ice_0662_RF.png
# ------------------------------
# count: 344
# 증강된 엣지 저장 완료: black_ice_0103_RF.png
# ------------------------------
# count: 345
# 증강된 엣지 저장 완료: black_ice_1134_RF.png
# ...

# %%
import albumentations as A
import cv2
import os

root_dir = '/content/drive/MyDrive/Dataset/Train/'
save_dir = '/content/drive/MyDrive/Dataset/Train/'

count = 1
aug = A.GaussNoise(var_limit=(25.0, 75.0), mean=50.0, p=1)

for img_list in data_images:
    img_name = img_list.split('.')[0]
    image = cv2.imread(root_dir+'Img/{}.jpg'.format(img_name))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # mask = cv2.imread(root_dir+'Mask/{}.png'.format(img_name))
    mask = cv2.imread(root_dir+'Edge/{}.png'.format(img_name))

    augmented = aug(image=image, mask=mask)
    image_gn = augmented['image']
    mask_gn = augmented['mask']

    print('count: {}'.format(count))
    # cv2.imwrite(save_dir+'/Img/'+'{}_GN.jpg'.format(img_name), image_gn)
    # print('증강된 이미지 저장 완료: {}_GN.jpg'.format(img_name))
    # cv2.imwrite(save_dir+'/Mask/'+'{}_GN.png'.format(img_name), mask_gn)
    # print('증강된 마스크 저장 완료: {}_GN.png'.format(img_name))
    cv2.imwrite(save_dir+'/Edge/'+'{}_GN.png'.format(img_name), mask_gn)
    print('증강된 엣지 저장 완료: {}_GN.png'.format(img_name))
    print('-'*30)

    count += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 증강된 엣지 저장 완료: black_ice_0543_GN.png
# ------------------------------
# count: 335
# 증강된 엣지 저장 완료: black_ice_1838_GN.png
# ------------------------------
# count: 336
# 증강된 엣지 저장 완료: black_ice_1842_GN.png
# ------------------------------
# count: 337
# 증강된 엣지 저장 완료: black_ice_0813_GN.png
# ------------------------------
# count: 338
# 증강된 엣지 저장 완료: black_ice_1706_GN.png
# ------------------------------
# count: 339
# 증강된 엣지 저장 완료: black_ice_0104_GN.png
# ------------------------------
# count: 340
# 증강된 엣지 저장 완료: black_ice_1184_GN.png
# ------------------------------
# count: 341
# 증강된 엣지 저장 완료: black_ice_0864_GN.png
# ------------------------------
# count: 342
# 증강된 엣지 저장 완료: black_ice_1680_GN.png
# ------------------------------
# count: 343
# 증강된 엣지 저장 완료: black_ice_0662_GN.png
# ------------------------------
# count: 344
# 증강된 엣지 저장 완료: black_ice_0103_GN.png
# ------------------------------
# count: 345
# 증강된 엣지 저장 완료: black_ice_1134_GN.png
# ...

# %%
import albumentations as A
import cv2
import os

root_dir = '/content/drive/MyDrive/Dataset/Train/'
save_dir = '/content/drive/MyDrive/Dataset/Train/'

count = 1
aug = A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.2, p=1)

for img_list in data_images:
    img_name = img_list.split('.')[0]
    image = cv2.imread(root_dir+'Img/{}.jpg'.format(img_name))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # mask = cv2.imread(root_dir+'Mask/{}.png'.format(img_name))
    mask = cv2.imread(root_dir+'Edge/{}.png'.format(img_name))

    augmented = aug(image=image, mask=mask)
    image_rbc = augmented['image']
    mask_rbc = augmented['mask']

    print('count: {}'.format(count))
    # cv2.imwrite(save_dir+'/Img/'+'{}_RBC.jpg'.format(img_name), image_rbc)
    # print('증강된 이미지 저장 완료: {}_RBC.jpg'.format(img_name))
    # cv2.imwrite(save_dir+'/Mask/'+'{}_RBC.png'.format(img_name), mask_rbc)
    # print('증강된 마스크 저장 완료: {}_RBC.png'.format(img_name))
    cv2.imwrite(save_dir+'/Edge/'+'{}_RBC.png'.format(img_name), mask_rbc)
    print('증강된 엣지 저장 완료: {}_RBC.png'.format(img_name))
    print('-'*30)

    count += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 증강된 엣지 저장 완료: black_ice_0543_RBC.png
# ------------------------------
# count: 335
# 증강된 엣지 저장 완료: black_ice_1838_RBC.png
# ------------------------------
# count: 336
# 증강된 엣지 저장 완료: black_ice_1842_RBC.png
# ------------------------------
# count: 337
# 증강된 엣지 저장 완료: black_ice_0813_RBC.png
# ------------------------------
# count: 338
# 증강된 엣지 저장 완료: black_ice_1706_RBC.png
# ------------------------------
# count: 339
# 증강된 엣지 저장 완료: black_ice_0104_RBC.png
# ------------------------------
# count: 340
# 증강된 엣지 저장 완료: black_ice_1184_RBC.png
# ------------------------------
# count: 341
# 증강된 엣지 저장 완료: black_ice_0864_RBC.png
# ------------------------------
# count: 342
# 증강된 엣지 저장 완료: black_ice_1680_RBC.png
# ------------------------------
# count: 343
# 증강된 엣지 저장 완료: black_ice_0662_RBC.png
# ------------------------------
# count: 344
# 증강된 엣지 저장 완료: black_ice_0103_RBC.png
# ------------------------------
# count: 345
# ...

# %%
import albumentations as A
import cv2
import os

root_dir = '/content/drive/MyDrive/Dataset/Train/'
save_dir = '/content/drive/MyDrive/Dataset/Train/'

count = 1
aug = A.Affine(translate_percent={'y':-.12}, p=1)

for img_list in data_images:
    img_name = img_list.split('.')[0]
    image = cv2.imread(root_dir+'Img/{}.jpg'.format(img_name))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # mask = cv2.imread(root_dir+'Mask/{}.png'.format(img_name))
    mask = cv2.imread(root_dir+'Edge/{}.png'.format(img_name))

    augmented = aug(image=image, mask=mask)
    image_ty = augmented['image']
    mask_ty = augmented['mask']

    print('count: {}'.format(count))
    # cv2.imwrite(save_dir+'/Img/'+'{}_TY.jpg'.format(img_name), image_ty)
    # print('증강된 이미지 저장 완료: {}_TY.jpg'.format(img_name))
    # cv2.imwrite(save_dir+'/Mask/'+'{}_TY.png'.format(img_name), mask_ty)
    # print('증강된 마스크 저장 완료: {}_TY.png'.format(img_name))
    cv2.imwrite(save_dir+'/Edge/'+'{}_TY.png'.format(img_name), mask_ty)
    print('증강된 엣지 저장 완료: {}_TY.png'.format(img_name))
    print('-'*30)

    count += 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 증강된 엣지 저장 완료: black_ice_0543_TY.png
# ------------------------------
# count: 335
# 증강된 엣지 저장 완료: black_ice_1838_TY.png
# ------------------------------
# count: 336
# 증강된 엣지 저장 완료: black_ice_1842_TY.png
# ------------------------------
# count: 337
# 증강된 엣지 저장 완료: black_ice_0813_TY.png
# ------------------------------
# count: 338
# 증강된 엣지 저장 완료: black_ice_1706_TY.png
# ------------------------------
# count: 339
# 증강된 엣지 저장 완료: black_ice_0104_TY.png
# ------------------------------
# count: 340
# 증강된 엣지 저장 완료: black_ice_1184_TY.png
# ------------------------------
# count: 341
# 증강된 엣지 저장 완료: black_ice_0864_TY.png
# ------------------------------
# count: 342
# 증강된 엣지 저장 완료: black_ice_1680_TY.png
# ------------------------------
# count: 343
# 증강된 엣지 저장 완료: black_ice_0662_TY.png
# ------------------------------
# count: 344
# 증강된 엣지 저장 완료: black_ice_0103_TY.png
# ------------------------------
# count: 345
# 증강된 엣지 저장 완료: black_ice_1134_TY.png
# ...
